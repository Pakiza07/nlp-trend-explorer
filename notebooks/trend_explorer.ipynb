# %% [markdown]
# # NLP Trend Explorer
#
# An NLP-based analytics system for exploring
# topic trends, sentiment patterns,
# and semantic relationships in financial news data.
#
# ## Features
#
# - Text preprocessing using spaCy
# - Sentiment analysis with VADER
# - Topic modeling using LDA
# - Trend and anomaly detection
# - Semantic search using sentence embeddings

# %% [markdown]
# ## Dataset Overview

# %%
import pandas as pd

df = pd.read_csv("../data/processed/clean_data.csv")

df.head()

# %%
df.info()

# %% [markdown]
# ## Topic Modeling Results

# %%
df['topic'].value_counts()

# %% [markdown]
# The dataset is primarily dominated by Stock Market topics,
# followed by Company News and Financial Personalities.

# %% [markdown]
# ## Topic Trends Over Time

# %%
from IPython.display import Image

Image(filename="../outputs/topic_volume_trends.png")

# %% [markdown]
# The visualization shows relatively stable activity
# with several noticeable spikes in Company News topics.

# %% [markdown]
# ## Sentiment Trends

# %%
Image(filename="../outputs/sentiment_trends.png")

# %% [markdown]
# Company News displayed the highest sentiment volatility,
# including several sharp polarity reversals.

# %% [markdown]
# ## Pattern Detection

# %%
agg_df = pd.read_csv("../data/processed/aggregated_data.csv")

agg_df.head()

# %% [markdown]
# Several weeks showed unusually large shifts
# in sentiment and article volume.
#
# These spikes were primarily concentrated
# within Company News topics.

# %% [markdown]
# ## Semantic Search Demo

# %%
import sys
import os
sys.path.append("../src")

from semantic_search import semantic_search

# %%
semantic_search("stock market crash")

# %%
semantic_search("company earnings report")

# %%
semantic_search("financial analysts prediction")

# %% [markdown]
# ## Key Insights

# %% [markdown]
# - Stock Market was the dominant topic across the dataset.
# - Company News exhibited the highest volatility in both sentiment and volume.
# - Topic activity remained mostly stable with several isolated spikes.
# - Semantic search successfully retrieved contextually related financial texts.
